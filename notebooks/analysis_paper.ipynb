# %% [markdown]
# # THRESHOLD: Main results

# %% [markdown]
# ## Preamble

# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams.update({'font.size': 15})
plt.rc('axes', labelsize=20)
plt.rcParams['xtick.labelsize'] = 20
plt.rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
plt.rcParams['pdf.fonttype'] = 42

module_path = os.path.abspath('../src/')
if module_path not in sys.path:
    sys.path.append(module_path)

import utils as ut
import plots as pt

path_cwd = os.getcwd()
print(path_cwd)
# Out:
# /Users/alfonso/workshop/threshold/notebooks

# %% [markdown]
# ## Homogeneous thresholds

# %%
model_region = 'National'
target_vaccination = [0.001, 0.005, 0.01, 0.05]

pt.plot_panel_homogeneous_thresholds_heatmaps(
    model_region=model_region, 
    target_vaccination=target_vaccination,
    path_cwd=os.path.join(path_cwd, '..'),
    cutoff_prevalence=0.001,
    )
# Out:
# /Users/alfonso/workshop/threshold/src/plots.py:115: RuntimeWarning: invalid value encountered in scalar divide
#   norm_change = (dict_stats[(fa, th, rv, fz)]['convinced']['mean'] - fa) / max_change
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %%
model_region = 'National'
target_vaccination = [0.001, 0.005, 0.01, 0.05]

pt.plot_panel_homogeneous_thresholds_sections(
    model_region=model_region, 
    target_vaccination=target_vaccination,
    path_cwd=os.path.join(path_cwd, '..'),
    cutoff_prevalence=0.001,
    curve_spacing=2,
    )
# Out:
# /Users/alfonso/workshop/threshold/src/plots.py:303: RuntimeWarning: invalid value encountered in scalar divide
#   norm_change = (dict_stats[(fa, th, rv, fz)]['convinced']['mean'] - fa) / max_change
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %% [markdown]
# ## Survey-based thresholds

# %%
pt.plot_panel_survey_thresholds_vaccination_curves(
        model_opinion='DD',
        path_cwd=os.path.join(path_cwd, '..'),
        cutoff_prevalence=0.0001,
        )
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %%
pt.plot_panel_survey_thresholds_correlation_curves( 
        model_opinion='DD',
        path_cwd=os.path.join(path_cwd, '..'),
        cutoff_prevalence=0.001,
        list_outliers=['Alaska'],
        )
# Out:
# alpha=0.0001, corr_already=-0.9965656215197092, corr_soon=-0.0918811885141368, corr_most=0.5082506222937312, corr_never=0.18234679716606925
# alpha=0.000126, corr_already=-0.9961456995481491, corr_soon=-0.10131013941281375, corr_most=0.5132112444054184, corr_never=0.19028220481317967
# alpha=0.000158, corr_already=-0.9956302955414024, corr_soon=-0.10540100989721017, corr_most=0.5130046487179444, corr_never=0.19648151696188076
# alpha=0.0002, corr_already=-0.994497538020676, corr_soon=-0.12109635520233175, corr_most=0.5188002559029501, corr_never=0.2115720209602698
# alpha=0.000251, corr_already=-0.9932015352072237, corr_soon=-0.13157493035464152, corr_most=0.5216566267335068, corr_never=0.22399815025005945
# alpha=0.000316, corr_already=-0.9913068622669384, corr_soon=-0.14630749721912586, corr_most=0.5263057586913709, corr_never=0.2396927932307381
# alpha=0.000398, corr_already=-0.9885445333220024, corr_soon=-0.16736917959047354, corr_most=0.5359985480960717, corr_never=0.25767410760994486
# alpha=0.000501, corr_already=-0.9843765408585882, corr_soon=-0.19054909134808118, corr_most=0.5404510781901014, corr_never=0.28323222449777774
# alpha=0.000631, corr_already=-0.978567226846989, corr_soon=-0.2209265712954845, corr_most=0.551369290858746, corr_never=0.3124965355336051
# alpha=0.000794, corr_already=-0.9696703175624701, corr_soon=-0.2555760615509562, corr_most=0.5607949313605811, corr_never=0.34938714183808395
